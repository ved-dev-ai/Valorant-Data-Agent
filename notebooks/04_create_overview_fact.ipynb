# %%
import pandas as pd
from pathlib import Path

# %%
# Paths
BASE = Path("../data/clean/vct_2024")
OUT = Path("../data/gold/facts")
DIM = Path("../data/gold/dimensions")

OUT.mkdir(parents=True, exist_ok=True)

# %%
# Silver source
overview = pd.read_parquet(
    BASE / "matches/overview.parquet"
)

# Dimensions
dim_player = pd.read_parquet(DIM / "dim_player.parquet")
dim_team = pd.read_parquet(DIM / "dim_team.parquet")
dim_tournament = pd.read_parquet(DIM / "dim_tournament.parquet")
dim_match = pd.read_parquet(DIM / "dim_match.parquet")
dim_map = pd.read_parquet(DIM / "dim_map.parquet")
dim_agent = pd.read_parquet(DIM / "dim_agent.parquet")

# %%
# Remove aggregate rows
overview = overview[
    overview["map_name"] != "All Maps"
].copy()

# %%
overview.head()
# Out:
#            tournament_name   stage_name match_type_name          match_name  \
# 0  Valorant Champions 2024  Group Stage     Opening (B)  Gen.G vs Sentinels
# 1  Valorant Champions 2024  Group Stage     Opening (B)  Gen.G vs Sentinels
# 2  Valorant Champions 2024  Group Stage     Opening (B)  Gen.G vs Sentinels
# 3  Valorant Champions 2024  Group Stage     Opening (B)  Gen.G vs Sentinels
# 4  Valorant Champions 2024  Group Stage     Opening (B)  Gen.G vs Sentinels
#
#   map_name player_name team_name agent_name  rating  average_combat_score  \
# 0    Haven     t3xture     Gen.G       jett    1.60                 305.0
# 1    Haven     t3xture     Gen.G       jett    1.71                 364.0
# 2    Haven     t3xture     Gen.G       jett    1.52                 261.0
# 3    Haven      Meteor     Gen.G    killjoy    1.23                 221.0
# 4    Haven      Meteor     Gen.G    killjoy    1.16                 229.0
#
#    ...  deaths  assists  kills_deaths_ratio  \
# 0  ...    12.0      4.0                12.0
# 1  ...     5.0      2.0                 7.0
# 2  ...     7.0      2.0                 5.0
# 3  ...    10.0      4.0                 7.0
# 4  ...     4.0      1.0                 4.0
#
#    kill_assist_trade_survive_percentage  average_damage_per_round  \
# 0                                  0.81                     188.0
# 1                                  0.89                     216.0
# 2                                  0.75                     168.0
# 3                                  0.76                     140.0
# 4                                  0.78                     127.0
#
#    headshot_percentage  first_kills  first_deaths  first_kills_deaths_ratio  \
# 0                 0.31          3.0           4.0                      -1.0
# 1                 0.37          2.0           2.0                       0.0
# 2                 0.24          1.0           2.0                      -1.0
# 3                 0.26          1.0           4.0                      -3.0
# 4                 0.35          1.0           1.0                       0.0
#
#      side
# 0    both
# 1  attack
# 2  defend
# 3    both
# 4  attack
#
# [5 rows x 21 columns]

# %%
fact = overview.merge(
    dim_player,
    on="player_name",
    how="left"
)

# %%
print(fact['player_id'].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_team,
    on="team_name",
    how="left"
)

# %%
print(fact['team_id'].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_tournament,
    on=[
        "tournament_name",
        "stage_name",
        "match_type_name"
    ],
    how="left"
)

# %%
print(fact["tournament_id"].isna().sum())
# Out:
# 0

# %%
fact.columns
# Out:
# Index(['tournament_name', 'stage_name', 'match_type_name', 'match_name',
#        'map_name', 'player_name', 'team_name', 'agent_name', 'rating',
#        'average_combat_score', 'kills', 'deaths', 'assists',
#        'kills_deaths_ratio', 'kill_assist_trade_survive_percentage',
#        'average_damage_per_round', 'headshot_percentage', 'first_kills',
#        'first_deaths', 'first_kills_deaths_ratio', 'side', 'player_id',
#        'team_id', 'tournament_id', 'stage_id', 'match_type_id'],
#       dtype='str')

# %%
dim_match.columns
# Out:
# Index(['match_id', 'game_id', 'match_name', 'map_name', 'tournament_id',
#        'stage_id', 'match_type_id'],
#       dtype='str')

# %%
fact = fact.merge(
    dim_match,
    on=[
        "tournament_id",
        "stage_id",
        "match_type_id",
        "match_name",
        "map_name"
    ],
    how="left"
)

# %%
print(fact["match_id"].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_map,
    on="map_name",
    how="left"
)

# %%
print(fact["map_id"].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_agent,
    on="agent_name",
    how="left"
)

# %%
print(fact["agent_id"].isna().sum())
# Out:
# 0

# %%
fact.columns
# Out:
# Index(['tournament_name', 'stage_name', 'match_type_name', 'match_name',
#        'map_name', 'player_name', 'team_name', 'agent_name', 'rating',
#        'average_combat_score', 'kills', 'deaths', 'assists',
#        'kills_deaths_ratio', 'kill_assist_trade_survive_percentage',
#        'average_damage_per_round', 'headshot_percentage', 'first_kills',
#        'first_deaths', 'first_kills_deaths_ratio', 'side', 'player_id',
#        'team_id', 'tournament_id', 'stage_id', 'match_type_id', 'match_id',
#        'game_id', 'map_id', 'agent_id'],
#       dtype='str')

# %%
# Index(['tournament_name', 'stage_name', 'match_type_name', 'match_name',
#        'map_name', 'player_name', 'team_name', 'agent_name', 'rating',
#        'average_combat_score', 'kills', 'deaths', 'assists',
#        'kills_deaths_ratio', 'kill_assist_trade_survive_percentage',
#        'average_damage_per_round', 'headshot_percentage', 'first_kills',
#        'first_deaths', 'first_kills_deaths_ratio', 'side', 'player_id',
#        'team_id', 'tournament_id', 'stage_id', 'match_type_id', 'match_id',
#        'game_id', 'map_id', 'agent_id'],
#       dtype='str')

fact_player_match_map_stats = fact[
    [
        # Keys
        "match_id",
        "game_id",

        "player_id",
        "team_id",

        "tournament_id",
        "stage_id",
        "match_type_id",

        "map_id",
        "agent_id",

        "side",

        # Metrics
        "rating",
        "average_combat_score",
        "kills",
        "deaths",
        "assists",
        "kills_deaths_ratio",
        "kill_assist_trade_survive_percentage",
        "average_damage_per_round",
        "headshot_percentage",
        "first_kills",
        "first_deaths",
        "first_kills_deaths_ratio"
    ]
].copy()

# %%
fact_player_match_map_stats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   match_id                              33120 non-null  int64
#  1   game_id                               33120 non-null  int64
#  2   player_id                             33120 non-null  int64
#  3   team_id                               33120 non-null  int64
#  4   tournament_id                         33120 non-null  int64
#  5   stage_id                              33120 non-null  int64
#  6   match_type_id                         33120 non-null  int64
#  7   map_id                                33120 non-null  int64
#  8   agent_id                              33120 non-null  int64
#  9   side                                  33120 non-null  category
#  10  rating                                24450 non-null  float64
#  11  average_combat_score                  27331 non-null  float64
#  12  kills                                 27340 non-null  float64
#  13  deaths                                27340 non-null  float64
#  14  assists                               27340 non-null  float64
#  15  kills_deaths_ratio                    27338 non-null  float64
#  16  kill_assist_trade_survive_percentage  24440 non-null  float64
#  17  average_damage_per_round              25919 non-null  float64
#  18  headshot_percentage                   25902 non-null  float64
#  19  first_kills                           25930 non-null  float64
#  20  first_deaths                          25930 non-null  float64
#  21  first_kills_deaths_ratio              25930 non-null  float64
# dtypes: category(1), float64(12), int64(9)
# memory usage: 5.3 MB

# %%
fact_player_match_map_stats.isna().sum()
# Out:
# match_id                                   0
# game_id                                    0
# player_id                                  0
# team_id                                    0
# tournament_id                              0
# stage_id                                   0
# match_type_id                              0
# map_id                                     0
# agent_id                                   0
# side                                       0
# rating                                  8670
# average_combat_score                    5789
# kills                                   5780
# deaths                                  5780
# assists                                 5780
# kills_deaths_ratio                      5782
# kill_assist_trade_survive_percentage    8680
# average_damage_per_round                7201
# headshot_percentage                     7218
# first_kills                             7190
# first_deaths                            7190
# first_kills_deaths_ratio                7190
# dtype: int64

# %%
fact_player_match_map_stats
# Out:
#        match_id  game_id  player_id  team_id  tournament_id  stage_id  \
# 0        378662   180369       9196       17           2097      4035
# 1        378662   180369       9196       17           2097      4035
# 2        378662   180369       9196       17           2097      4035
# 3        378662   180369      13039       17           2097      4035
# 4        378662   180369      13039       17           2097      4035
# ...         ...      ...        ...      ...            ...       ...
# 33115    297258   155777       2489       17           1924      3723
# 33116    297258   155777       2489       17           1924      3723
# 33117    297258   155777        773       17           1924      3723
# 33118    297258   155777        773       17           1924      3723
# 33119    297258   155777        773       17           1924      3723
#
#        match_type_id  map_id  agent_id    side  ...  kills  deaths  assists  \
# 0              26223       7        12    both  ...   24.0    12.0      4.0
# 1              26223       7        12  attack  ...   12.0     5.0      2.0
# 2              26223       7        12  defend  ...   12.0     7.0      2.0
# 3              26223       7        14    both  ...   17.0    10.0      4.0
# 4              26223       7        14  attack  ...    8.0     4.0      1.0
# ...              ...     ...       ...     ...  ...    ...     ...      ...
# 33115          23316       3        25  attack  ...    8.0     6.0      2.0
# 33116          23316       3        25  defend  ...    5.0     4.0      2.0
# 33117          23316       3        21    both  ...   10.0     9.0      8.0
# 33118          23316       3        21  attack  ...    6.0     6.0      6.0
# 33119          23316       3        21  defend  ...    4.0     3.0      2.0
#
#        kills_deaths_ratio  kill_assist_trade_survive_percentage  \
# 0                    12.0                                  0.81
# 1                     7.0                                  0.89
# 2                     5.0                                  0.75
# 3                     7.0                                  0.76
# 4                     4.0                                  0.78
# ...                   ...                                   ...
# 33115                 2.0                                  0.83
# 33116                 1.0                                  0.80
# 33117                 1.0                                  1.00
# 33118                 0.0                                  1.00
# 33119                 1.0                                  1.00
#
#        average_damage_per_round  headshot_percentage  first_kills  \
# 0                         188.0                 0.31          3.0
# 1                         216.0                 0.37          2.0
# 2                         168.0                 0.24          1.0
# 3                         140.0                 0.26          1.0
# 4                         127.0                 0.35          1.0
# ...                         ...                  ...          ...
# 33115                     119.0                 0.41          1.0
# 33116                     150.0                 0.12          2.0
# 33117                      90.0                 0.25          1.0
# 33118                      98.0                 0.31          0.0
# 33119                      72.0                 0.13          1.0
#
#        first_deaths  first_kills_deaths_ratio
# 0               4.0                      -1.0
# 1               2.0                       0.0
# 2               2.0                      -1.0
# 3               4.0                      -3.0
# 4               1.0                       0.0
# ...             ...                       ...
# 33115           2.0                      -1.0
# 33116           0.0                       2.0
# 33117           0.0                       1.0
# 33118           0.0                       0.0
# 33119           0.0                       1.0
#
# [33120 rows x 22 columns]

# %%
out_path = OUT / "fact_player_match_map_stats.parquet"

fact_player_match_map_stats.to_parquet(
    out_path,
    index=False
)
