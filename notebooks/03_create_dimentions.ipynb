# %%
import pandas as pd
from pathlib import Path

# %%
# Paths
BASE = Path("../data/clean/vct_2024")
OUT = Path("../data/gold/dimensions")

OUT.mkdir(parents=True, exist_ok=True)

# %%
players_raw = pd.read_parquet(BASE / "ids/players_ids.parquet")

# %%
players_raw.head()
# Out:
#   player_name  player_id
# 0     t3xture       9196
# 1      Meteor      13039
# 2       Lakia        773
# 3       Karon      34974
# 4    Munchkin       2489

# %%
dim_players = players_raw[["player_id", "player_name"]].drop_duplicates().sort_values("player_id").reset_index(drop=True)

# %%
output_path = OUT / "dim_player.parquet"

dim_players.to_parquet(output_path, index=False)

# %%
teams_raw = pd.read_parquet(BASE / "ids/teams_ids.parquet")

# %%
teams_raw.head()
# Out:
#          team_name  team_id
# 0            Gen.G       17
# 1        Sentinels        2
# 2  FunPlus Phoenix    11328
# 3    Team Heretics     1001
# 4              DRX     8185

# %%
dim_teams = teams_raw[["team_id", "team_name"]].drop_duplicates().sort_values("team_id").reset_index(drop=True)

# %%
output_path = OUT / "dim_team.parquet"

dim_teams.to_parquet(output_path, index=False)

# %%
t_raw = pd.read_parquet(BASE / "ids/tournaments_stages_match_types_ids.parquet")

# %%
t_raw.head()
# Out:
#            tournament_name  tournament_id stage_name  stage_id  \
# 0  Valorant Champions 2024           2097   Playoffs      4131
# 1  Valorant Champions 2024           2097   Playoffs      4131
# 2  Valorant Champions 2024           2097   Playoffs      4131
# 3  Valorant Champions 2024           2097   Playoffs      4131
# 4  Valorant Champions 2024           2097   Playoffs      4131
#
#        match_type_name  match_type_id
# 0  Upper Quarterfinals          26235
# 1     Upper Semifinals          26236
# 2          Upper Final          26237
# 3          Grand Final          26238
# 4        Lower Round 1          26239

# %%
dim_tournament = (
    t_raw[
        [
            "tournament_id",
            "tournament_name",
            "stage_id",
            "stage_name",
            "match_type_id",
            "match_type_name",
        ]
    ]
    .drop_duplicates()
    .sort_values(
        ["tournament_id", "stage_id", "match_type_id"]
    )
    .reset_index(drop=True)
)

# %%
dim_tournament.head()
# Out:
#    tournament_id                      tournament_name  stage_id   stage_name  \
# 0           1921  Champions Tour 2024: Masters Madrid      3663  Swiss Stage
# 1           1921  Champions Tour 2024: Masters Madrid      3663  Swiss Stage
# 2           1921  Champions Tour 2024: Masters Madrid      3663  Swiss Stage
# 3           1921  Champions Tour 2024: Masters Madrid      3821     Playoffs
# 4           1921  Champions Tour 2024: Masters Madrid      3821     Playoffs
#
#    match_type_id   match_type_name
# 0          23896           Round 1
# 1          23902           Round 2
# 2          23903           Round 3
# 3          23897  Upper Semifinals
# 4          23898       Upper Final

# %%
dim_tournament.to_parquet(
    OUT / "dim_tournament.parquet",
    index=False
)

# %%
valorant_maps = [
    "Ascent",
    "Bind",
    "Breeze",
    "Corrode",
    "Fracture",
    "Haven",
    "Icebox",
    "Lotus",
    "Pearl",
    "Split",
    "Sunset",
    "Abyss"
]


valorant_agents = [
    "Astra",
    "Breach",
    "Brimstone",
    "Chamber",
    "Clove",
    "Cypher",
    "Deadlock",
    "Fade",
    "Gekko",
    "Harbor",
    "Iso",
    "Jett",
    "KayO",
    "Killjoy",
    "Neon",
    "Omen",
    "Phoenix",
    "Raze",
    "Reyna",
    "Sage",
    "Skye",
    "Sova",
    "Tejo",
    "Viper",
    "Veto",
    "Vyse",
    "Waylay",
    "Yoru"
]

# %%
valorant_agents = [agent.lower() for agent in valorant_agents]

# %%
dim_map = pd.DataFrame({
    "map_name": sorted(valorant_maps)
})

dim_map["map_id"] = dim_map.index + 1

dim_map = dim_map[["map_id", "map_name"]]

# %%
dim_map_path = OUT / "dim_map.parquet"

dim_map.to_parquet(dim_map_path, index=False)

# %%
dim_agent = pd.DataFrame({
    "agent_name": sorted(valorant_agents)
})

dim_agent["agent_id"] = dim_agent.index + 1

dim_agent = dim_agent[["agent_id", "agent_name"]]

# %%
dim_agent_path = OUT / "dim_agent.parquet"

dim_agent.to_parquet(dim_agent_path, index=False)

# %%
m_raw = pd.read_parquet(BASE / "ids/tournaments_stages_matches_games_ids.parquet")
t_raw = pd.read_parquet(BASE / "ids/tournaments_stages_match_types_ids.parquet")

# %%
m_raw.head()
# Out:
#            tournament_name  tournament_id   stage_name  stage_id  \
# 0  Valorant Champions 2024           2097  Group Stage      4035
# 1  Valorant Champions 2024           2097  Group Stage      4035
# 2  Valorant Champions 2024           2097  Group Stage      4035
# 3  Valorant Champions 2024           2097  Group Stage      4035
# 4  Valorant Champions 2024           2097  Group Stage      4035
#
#   match_type_name                        match_name  match_id map_name  \
# 0     Opening (B)                Gen.G vs Sentinels    378662    Haven
# 1     Opening (B)                Gen.G vs Sentinels    378662   Ascent
# 2     Opening (B)  FunPlus Phoenix vs Team Heretics    378663    Abyss
# 3     Opening (B)  FunPlus Phoenix vs Team Heretics    378663     Bind
# 4     Opening (B)  FunPlus Phoenix vs Team Heretics    378663    Lotus
#
#    game_id
# 0   180369
# 1   180370
# 2   180372
# 3   180373
# 4   180374

# %%
m_merged = m_raw.merge(
    t_raw[
        [
            "tournament_name",
            "stage_name",
            "match_type_name",
            "match_type_id",
        ]
    ],
    on=[
        "tournament_name",
        "stage_name",
        "match_type_name",
    ],
    how="left"
)

# %%
m_merged.columns
# Out:
# Index(['tournament_name', 'tournament_id', 'stage_name', 'stage_id',
#        'match_type_name', 'match_name', 'match_id', 'map_name', 'game_id',
#        'match_type_id'],
#       dtype='str')

# %%
dim_match = (
    m_merged[
        [
            "match_id",
            "game_id",
            "match_name",
            "map_name",
            "tournament_id",
            "stage_id",
            "match_type_id",
        ]
    ]
    .drop_duplicates()
    .sort_values(["match_id", "game_id"])
    .reset_index(drop=True)
)

# %%
dim_match.head()
# Out:
#    match_id  game_id            match_name map_name  tournament_id  stage_id  \
# 0    295605   153722  NRG Esports vs FURIA   Breeze           1923      3637
# 1    295605   153723  NRG Esports vs FURIA   Ascent           1923      3637
# 2    295606   153725        Cloud9 vs MIBR     Bind           1923      3637
# 3    295606   153726        Cloud9 vs MIBR    Split           1923      3637
# 4    295606   153727        Cloud9 vs MIBR    Lotus           1923      3637
#
#    match_type_id
# 0          23017
# 1          23017
# 2          23017
# 3          23017
# 4          23017

# %%
dim_match_path = OUT / "dim_match.parquet"

dim_match.to_parquet(dim_match_path, index=False)
