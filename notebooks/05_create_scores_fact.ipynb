# %%
import pandas as pd
from pathlib import Path

BASE = Path("../data/clean/vct_2024")
DIM = Path("../data/gold/dimensions")
OUT = Path("../data/gold/facts")

OUT.mkdir(parents=True, exist_ok=True)

# %%
# Silver source
scores = pd.read_parquet(
    BASE / "matches/scores.parquet"
)

# Dimensions
dim_team = pd.read_parquet(DIM / "dim_team.parquet")
dim_match = pd.read_parquet(DIM / "dim_match.parquet")
dim_tournament = pd.read_parquet(DIM / "dim_tournament.parquet")

# %%
fact = scores.merge(
    dim_team,
    left_on="team_a_name",
    right_on="team_name",
    how="left"
).rename(
    columns={"team_id": "team_a_id"}
)

# %%
fact = fact.drop(columns=["team_name"])

# %%
print(fact["team_a_id"].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_team,
    left_on="team_b_name",
    right_on="team_name",
    how="left"
).rename(
    columns={"team_id": "team_b_id"}
)

# %%
fact = fact.drop(columns=["team_name"])

# %%
print(fact['team_b_id'].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_team,
    left_on="winning_team_name",
    right_on="team_name",
    how="left"
).rename(
    columns={"team_id": "winning_team_id"}
)

# %%
fact = fact.drop(columns=["team_name"])

# %%
print(fact["winning_team_id"].isna().sum())
# Out:
# 0

# %%
fact = fact.merge(
    dim_tournament,
    on=[
        "tournament_name",
        "stage_name",
        "match_type_name"
    ],
    how="left"
)

# %%
print(fact["tournament_id"].isna().sum())
# Out:
# 0

# %%
dim_match
# Out:
#       match_id  game_id                  match_name map_name  tournament_id  \
# 0       295605   153722        NRG Esports vs FURIA   Breeze           1923
# 1       295605   153723        NRG Esports vs FURIA   Ascent           1923
# 2       295606   153725              Cloud9 vs MIBR     Bind           1923
# 3       295606   153726              Cloud9 vs MIBR    Split           1923
# 4       295606   153727              Cloud9 vs MIBR    Lotus           1923
# ...        ...      ...                         ...      ...            ...
# 1099    378835   180454  Team Heretics vs Sentinels    Abyss           2097
# 1100    378836   180455   LEVIATÁN vs Team Heretics   Icebox           2097
# 1101    378836   180456   LEVIATÁN vs Team Heretics   Sunset           2097
# 1102    378836   180457   LEVIATÁN vs Team Heretics    Abyss           2097
# 1103    378836   180458   LEVIATÁN vs Team Heretics    Lotus           2097
#
#       stage_id  match_type_id
# 0         3637          23017
# 1         3637          23017
# 2         3637          23017
# 3         3637          23017
# 4         3637          23017
# ...        ...            ...
# 1099      4131          26241
# 1100      4131          26242
# 1101      4131          26242
# 1102      4131          26242
# 1103      4131          26242
#
# [1104 rows x 7 columns]

# %%
fact = fact.merge(
    dim_match[
        [
            "match_id",
            "match_name",
            "tournament_id",
            "stage_id",
            "match_type_id"
        ]
    ].drop_duplicates(),
    on=[
        "tournament_id",
        "stage_id",
        "match_type_id",
        "match_name"
    ],
    how="left"
)

# %%
print(fact["match_id"].isna().sum())
# Out:
# 0

# %%
fact_match_results = fact[
    [
        # Keys
        "match_id",

        "tournament_id",
        "stage_id",
        "match_type_id",

        "team_a_id",
        "team_b_id",
        "winning_team_id",

        # Scores
        "team_a_score",
        "team_b_score",
    ]
].copy()

# %%
print(fact_match_results.duplicated("match_id").sum())
# Out:
# 0

# %%
fact_match_results.isna().sum()
# Out:
# match_id           0
# tournament_id      0
# stage_id           0
# match_type_id      0
# team_a_id          0
# team_b_id          0
# winning_team_id    0
# team_a_score       0
# team_b_score       0
# dtype: int64

# %%
out_path = OUT / "fact_match_results.parquet"

fact_match_results.to_parquet(
    out_path,
    index=False
)
